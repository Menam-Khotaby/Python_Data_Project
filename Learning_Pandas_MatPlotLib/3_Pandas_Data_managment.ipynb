# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df["job_posted_date"])

# %%
df.sample(10)
# Out:
#                   job_title_short  \
# 551583               Data Analyst
# 694871             Data Scientist
# 514519           Business Analyst
# 395057               Data Analyst
# 461189               Data Analyst
# 77082           Software Engineer
# 348330               Data Analyst
# 334472  Machine Learning Engineer
# 596782              Data Engineer
# 179617               Data Analyst
#
#                                                 job_title  \
# 551583                                       Data Analyst
# 694871             Lead Data Scientist - multiple domains
# 514519                           Business Systems Analyst
# 395057                               100025 Data Analysis
# 461189                                       Data Analyst
# 77082                   IT Analyst (Software Development)
# 348330                                Global Data Analyst
# 334472  ML Engineer в команду суперприложения, Санкт-П...
# 596782                                  Data Engineer F/H
# 179617                     Remote Data Analyst / Contract
#
#                  job_location                         job_via  \
# 551583     Maharashtra, India                       via Shine
# 694871        Berlin, Germany  via SmartRecruiters Job Search
# 514519          Cork, Ireland                    via The Muse
# 395057        Santiago, Chile                       via BeBee
# 461189              Plano, TX                    via LinkedIn
# 77082               Singapore                 via Recruit.net
# 348330   Kabelsketal, Germany                       via BeBee
# 334472  St Petersburg, Russia                     via VK Team
# 596782          Paris, France                       via BeBee
# 179617               Anywhere                    via LinkedIn
#
#        job_schedule_type  job_work_from_home search_location  \
# 551583         Full-time               False           India
# 694871         Full-time               False         Germany
# 514519         Full-time               False         Ireland
# 395057         Full-time               False           Chile
# 461189        Contractor               False           Sudan
# 77082          Full-time               False       Singapore
# 348330         Full-time               False         Germany
# 334472         Full-time               False          Russia
# 596782         Full-time               False          France
# 179617         Full-time                True          Canada
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 551583 2023-11-11 19:09:35                   True                 False
# 694871 2023-04-11 11:12:34                  False                 False
# 514519 2023-07-13 11:28:46                  False                 False
# 395057 2023-12-08 18:35:02                   True                 False
# 461189 2023-11-07 15:03:10                   True                  True
# 77082  2023-07-05 00:13:53                  False                 False
# 348330 2023-09-14 23:12:42                   True                 False
# 334472 2023-08-01 23:32:25                  False                 False
# 596782 2023-11-23 09:22:59                  False                 False
# 179617 2023-08-21 15:21:03                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 551583       India        None              NaN              NaN
# 694871     Germany        None              NaN              NaN
# 514519     Ireland        None              NaN              NaN
# 395057       Chile        None              NaN              NaN
# 461189       Sudan        None              NaN              NaN
# 77082    Singapore        None              NaN              NaN
# 348330     Germany        None              NaN              NaN
# 334472      Russia        None              NaN              NaN
# 596782      France        None              NaN              NaN
# 179617      Canada        None              NaN              NaN
#
#                                company_name  \
# 551583                          Infosys BPM
# 694871                                 Wolt
# 514519                               NetApp
# 395057                            Santander
# 461189                              Akkodis
# 77082   Williams sonoma Singapore Pte. Ltd.
# 348330      envia Mitteldeutsche Energie AG
# 334472             Mail.Ru Group, ВКонтакте
# 596782            Le journal du Grand Paris
# 179617                            Trioworld
#
#                                                job_skills  \
# 551583  ['sql', 'shell', 'r', 'bigquery', 'pandas', 'l...
# 694871                                               None
# 514519  ['sql', 'python', 'nosql', 'oracle', 'snowflake']
# 395057                                               None
# 461189                                     ['sql', 'aws']
# 77082        ['c#', 'sql', 'word', 'excel', 'powerpoint']
# 348330                                               None
# 334472  ['python', 'java', 'scala', 'sql', 'spark', 'h...
# 596782  ['scala', 'python', 'java', 'sql', 'databricks...
# 179617                                       ['power bi']
#
#                                           job_type_skills
# 551583  {'analyst_tools': ['excel', 'tableau', 'qlik']...
# 694871                                               None
# 514519  {'cloud': ['oracle', 'snowflake'], 'programmin...
# 395057                                               None
# 461189         {'cloud': ['aws'], 'programming': ['sql']}
# 77082   {'analyst_tools': ['word', 'excel', 'powerpoin...
# 348330                                               None
# 334472  {'libraries': ['spark', 'hadoop'], 'programmin...
# 596782  {'cloud': ['databricks', 'azure', 'gcp', 'aws'...
# 179617                    {'analyst_tools': ['power bi']}

# %%
# Out:
# 8.851771767032648
# 69552
# 785741
