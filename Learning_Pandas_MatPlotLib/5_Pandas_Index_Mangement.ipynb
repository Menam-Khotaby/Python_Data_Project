# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df["job_posted_date"])

# %%
df.index.name = "Index"
df.head(5)
# Out:
#             job_title_short  \
# Index
# 0      Senior Data Engineer
# 1              Data Analyst
# 2             Data Engineer
# 3             Data Engineer
# 4             Data Engineer
#
#                                                job_title  \
# Index
# 0      Senior Clinical Data Engineer / Principal Clin...
# 1                                           Data Analyst
# 2      Data Engineer/Scientist/Analyst, Mid or Senior...
# 3      LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                 Data Engineer- Sr Jobs
#
#                        job_location             job_via job_schedule_type  \
# Index
# 0                     Watertown, CT     via Work Nearby         Full-time
# 1      Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2                   Berlin, Germany        via LinkedIn         Full-time
# 3                   San Antonio, TX   via Diversity.com         Full-time
# 4                    Washington, DC  via Clearance Jobs         Full-time
#
#        job_work_from_home       search_location     job_posted_date  \
# Index
# 0                   False  Texas, United States 2023-06-16 13:44:15
# 1                   False                Mexico 2023-01-14 13:18:07
# 2                   False               Germany 2023-10-10 13:14:55
# 3                   False  Texas, United States 2023-07-04 13:01:41
# 4                   False                 Sudan 2023-08-07 14:29:36
#
#        job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# Index
# 0                      False                 False  United States        None
# 1                      False                 False         Mexico        None
# 2                      False                 False        Germany        None
# 3                       True                 False  United States        None
# 4                      False                 False          Sudan        None
#
#        salary_year_avg  salary_hour_avg                  company_name  \
# Index
# 0                  NaN              NaN          Boehringer Ingelheim
# 1                  NaN              NaN    Hewlett Packard Enterprise
# 2                  NaN              NaN      ALPHA Augmented Services
# 3                  NaN              NaN  Southwest Research Institute
# 4                  NaN              NaN               Kristina Daniel
#
#                                               job_skills  \
# Index
# 0                                                   None
# 1      ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2      ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3      ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4      ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                          job_type_skills
# Index
# 0                                                   None
# 1      {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2      {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3      {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4      {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.index.dtype
# Out:
# dtype('int64')

# %%
df_anywhere = df[df['job_location'] == 'Anywhere']
df_anywhere.reset_index( inplace=True)
df_anywhere
# Out:
#         Index        job_title_short                                job_title  \
# 0           5          Data Engineer                        GCP Data Engineer
# 1           7          Data Engineer                            Data Engineer
# 2           9         Data Scientist                        Data Scientist II
# 3          24         Data Scientist            Data Scientist (DataLab Team)
# 4          51   Senior Data Engineer                     Senior Data Engineer
# ...       ...                    ...                                      ...
# 69547  785485           Data Analyst                     Data Quality Analyst
# 69548  785494  Senior Data Scientist                    Senior Data Scientist
# 69549  785645         Data Scientist                      Data Science Intern
# 69550  785654         Data Scientist                      Data Science Intern
# 69551  785703           Data Analyst  Data Analyst - CRYPTOGRAPHY - Full-time
#
#       job_location           job_via         job_schedule_type  \
# 0         Anywhere  via ZipRecruiter  Contractor and Temp work
# 1         Anywhere      via LinkedIn                 Full-time
# 2         Anywhere  via ZipRecruiter                 Full-time
# 3         Anywhere      via LinkedIn                 Full-time
# 4         Anywhere      via LinkedIn                Contractor
# ...            ...               ...                       ...
# 69547     Anywhere      via LinkedIn                 Full-time
# 69548     Anywhere      via LinkedIn                 Full-time
# 69549     Anywhere      via LinkedIn                Internship
# 69550     Anywhere      via LinkedIn                      None
# 69551     Anywhere      via Snagajob                 Full-time
#
#        job_work_from_home          search_location     job_posted_date  \
# 0                    True                  Georgia 2023-11-07 14:01:59
# 1                    True                  Romania 2023-12-07 13:40:49
# 2                    True  New York, United States 2023-04-23 13:02:57
# 3                    True                   Serbia 2023-06-27 13:46:46
# 4                    True  Illinois, United States 2023-06-21 13:09:39
# ...                   ...                      ...                 ...
# 69547                True           United Kingdom 2023-10-04 06:09:44
# 69548                True                    India 2023-01-15 06:12:09
# 69549                True                    India 2023-01-20 06:51:23
# 69550                True                    India 2023-01-31 06:11:46
# 69551                True     Texas, United States 2023-01-28 06:02:55
#
#        job_no_degree_mention  job_health_insurance     job_country  \
# 0                      False                 False   United States
# 1                      False                 False         Romania
# 2                      False                 False   United States
# 3                      False                 False          Serbia
# 4                      False                 False   United States
# ...                      ...                   ...             ...
# 69547                  False                 False  United Kingdom
# 69548                  False                 False           India
# 69549                  False                 False           India
# 69550                  False                 False           India
# 69551                   True                 False   United States
#
#       salary_rate  salary_year_avg  salary_hour_avg  \
# 0            None              NaN              NaN
# 1            None              NaN              NaN
# 2            None              NaN              NaN
# 3            None              NaN              NaN
# 4            hour              NaN             72.5
# ...           ...              ...              ...
# 69547        None              NaN              NaN
# 69548        None              NaN              NaN
# 69549        None              NaN              NaN
# 69550        None              NaN              NaN
# 69551        None              NaN              NaN
#
#                                             company_name  \
# 0                                        smart folks inc
# 1                                                  Zitec
# 2                             Radwell International, LLC
# 3                                                Semrush
# 4                                       Aditi Consulting
# ...                                                  ...
# 69547                                            Viatris
# 69548  GlobalEmployees - where Talent meets Opportunity!
# 69549                         TwiLearn EduTech Pvt. Ltd.
# 69550                                             Corizo
# 69551                        Axelon Services Corporation
#
#                                               job_skills  \
# 0                               ['python', 'sql', 'gcp']
# 1      ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 2      ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 3                                             ['python']
# 4       ['python', 'java', 'aws', 'databricks', 'spark']
# ...                                                  ...
# 69547       ['sql', 'sql server', 'excel', 'powerpoint']
# 69548  ['r', 'python', 'scala', 'java', 'sql', 'nosql...
# 69549                              ['python', 'tableau']
# 69550                                           ['zoom']
# 69551                                               None
#
#                                          job_type_skills
# 0      {'cloud': ['gcp'], 'programming': ['python', '...
# 1      {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 2      {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 3                            {'programming': ['python']}
# 4      {'cloud': ['aws', 'databricks'], 'libraries': ...
# ...                                                  ...
# 69547  {'analyst_tools': ['excel', 'powerpoint'], 'da...
# 69548  {'libraries': ['scikit-learn', 'numpy', 'tenso...
# 69549  {'analyst_tools': ['tableau'], 'programming': ...
# 69550                                 {'sync': ['zoom']}
# 69551                                               None
#
# [69552 rows x 18 columns]

# %%
df_anywhere.set_index('Index', inplace=True)
df_anywhere
# Out:
#               job_title_short                                job_title  \
# Index
# 5               Data Engineer                        GCP Data Engineer
# 7               Data Engineer                            Data Engineer
# 9              Data Scientist                        Data Scientist II
# 24             Data Scientist            Data Scientist (DataLab Team)
# 51       Senior Data Engineer                     Senior Data Engineer
# ...                       ...                                      ...
# 785485           Data Analyst                     Data Quality Analyst
# 785494  Senior Data Scientist                    Senior Data Scientist
# 785645         Data Scientist                      Data Science Intern
# 785654         Data Scientist                      Data Science Intern
# 785703           Data Analyst  Data Analyst - CRYPTOGRAPHY - Full-time
#
#        job_location           job_via         job_schedule_type  \
# Index
# 5          Anywhere  via ZipRecruiter  Contractor and Temp work
# 7          Anywhere      via LinkedIn                 Full-time
# 9          Anywhere  via ZipRecruiter                 Full-time
# 24         Anywhere      via LinkedIn                 Full-time
# 51         Anywhere      via LinkedIn                Contractor
# ...             ...               ...                       ...
# 785485     Anywhere      via LinkedIn                 Full-time
# 785494     Anywhere      via LinkedIn                 Full-time
# 785645     Anywhere      via LinkedIn                Internship
# 785654     Anywhere      via LinkedIn                      None
# 785703     Anywhere      via Snagajob                 Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# Index
# 5                     True                  Georgia 2023-11-07 14:01:59
# 7                     True                  Romania 2023-12-07 13:40:49
# 9                     True  New York, United States 2023-04-23 13:02:57
# 24                    True                   Serbia 2023-06-27 13:46:46
# 51                    True  Illinois, United States 2023-06-21 13:09:39
# ...                    ...                      ...                 ...
# 785485                True           United Kingdom 2023-10-04 06:09:44
# 785494                True                    India 2023-01-15 06:12:09
# 785645                True                    India 2023-01-20 06:51:23
# 785654                True                    India 2023-01-31 06:11:46
# 785703                True     Texas, United States 2023-01-28 06:02:55
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# Index
# 5                       False                 False   United States
# 7                       False                 False         Romania
# 9                       False                 False   United States
# 24                      False                 False          Serbia
# 51                      False                 False   United States
# ...                       ...                   ...             ...
# 785485                  False                 False  United Kingdom
# 785494                  False                 False           India
# 785645                  False                 False           India
# 785654                  False                 False           India
# 785703                   True                 False   United States
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# Index
# 5             None              NaN              NaN
# 7             None              NaN              NaN
# 9             None              NaN              NaN
# 24            None              NaN              NaN
# 51            hour              NaN             72.5
# ...            ...              ...              ...
# 785485        None              NaN              NaN
# 785494        None              NaN              NaN
# 785645        None              NaN              NaN
# 785654        None              NaN              NaN
# 785703        None              NaN              NaN
#
#                                              company_name  \
# Index
# 5                                         smart folks inc
# 7                                                   Zitec
# 9                              Radwell International, LLC
# 24                                                Semrush
# 51                                       Aditi Consulting
# ...                                                   ...
# 785485                                            Viatris
# 785494  GlobalEmployees - where Talent meets Opportunity!
# 785645                         TwiLearn EduTech Pvt. Ltd.
# 785654                                             Corizo
# 785703                        Axelon Services Corporation
#
#                                                job_skills  \
# Index
# 5                                ['python', 'sql', 'gcp']
# 7       ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 9       ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 24                                             ['python']
# 51       ['python', 'java', 'aws', 'databricks', 'spark']
# ...                                                   ...
# 785485       ['sql', 'sql server', 'excel', 'powerpoint']
# 785494  ['r', 'python', 'scala', 'java', 'sql', 'nosql...
# 785645                              ['python', 'tableau']
# 785654                                           ['zoom']
# 785703                                               None
#
#                                           job_type_skills
# Index
# 5       {'cloud': ['gcp'], 'programming': ['python', '...
# 7       {'cloud': ['gcp', 'azure', 'aws', 'bigquery', ...
# 9       {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 24                            {'programming': ['python']}
# 51      {'cloud': ['aws', 'databricks'], 'libraries': ...
# ...                                                   ...
# 785485  {'analyst_tools': ['excel', 'powerpoint'], 'da...
# 785494  {'libraries': ['scikit-learn', 'numpy', 'tenso...
# 785645  {'analyst_tools': ['tableau'], 'programming': ...
# 785654                                 {'sync': ['zoom']}
# 785703                                               None
#
# [69552 rows x 17 columns]
